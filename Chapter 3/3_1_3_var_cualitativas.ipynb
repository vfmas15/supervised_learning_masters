# %%
# Creación aleatoria de datos
import numpy as np
import random
random.seed(42)

# %%
nivel_estudios = []
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)

nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Grado' 'Master' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado'
#  'Doctorado' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Secundaria' 'Secundaria' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Master' 'Grado' 'Master'
#  'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Grado' 'Master' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Master'
#  'Bachillerato' 'Doctorado' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Master' 'Grado'
#  'Grado' 'Grado' 'Master' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria'
#  'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Doctorado' 'Doctorado'
#  'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Secundaria'
#  'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Secundaria' 'Master'
#  'Secundaria' 'Grado' 'Secundaria' 'Bachillerato' 'Master' 'Secundaria'
#  'Bachillerato' 'Grado' 'Master' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Secundaria' 'Grado' 'Bachillerato' 'Master' 'Bachillerato' 'Grado'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Grado' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Master' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Master' 'Grado' 'Secundaria'
#  'Bachillerato' 'Doctorado' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Grado'
#  'Grado' 'Grado' 'Master' 'Grado' 'Grado' 'Master' 'Grado' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Grado' 'Grado' 'Secundaria' 'Secundaria' 'Secundaria'
#  'Secundaria' 'Grado' 'Bachillerato' 'Doctorado' 'Bachillerato' 'Master'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Doctorado'
#  'Bachillerato' 'Master' 'Secundaria' 'Grado' 'Bachillerato' 'Master'
#  'Master' 'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Master' 'Secundaria' 'Bachillerato' 'Grado' 'Secundaria' 'Grado'
#  'Grado' 'Secundaria' 'Grado' 'Master' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Secundaria' 'Secundaria'
#  'Master' 'Bachillerato' 'Master' 'Grado' 'Grado' 'Secundaria'
#  'Secundaria' 'Master' 'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Doctorado' 'Grado' 'Bachillerato' 'Grado' 'Doctorado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Secundaria' 'Grado'
#  'Grado' 'Secundaria' 'Doctorado' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Master' 'Grado' 'Master' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Doctorado' 'Secundaria' 'Master' 'Grado' 'Grado'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Bachillerato' 'Master'
#  'Secundaria' 'Secundaria' 'Grado' 'Bachillerato' 'Master' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Doctorado'
#  'Bachillerato' 'Master' 'Secundaria' 'Grado' 'Bachillerato' 'Grado'
#  'Secundaria' 'Grado' 'Secundaria' 'Master' 'Master' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Master' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Master' 'Master' 'Bachillerato'
#  'Master' 'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Secundaria' 'Bachillerato' 'Doctorado' 'Grado' 'Bachillerato'
#  'Doctorado' 'Secundaria' 'Master' 'Grado' 'Secundaria' 'Master' 'Grado'
#  'Grado' 'Grado' 'Secundaria' 'Grado' 'Grado' 'Secundaria' 'Grado'
#  'Secundaria' 'Bachillerato' 'Grado' 'Doctorado' 'Doctorado' 'Grado'
#  'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Master' 'Grado'
#  'Bachillerato' 'Master' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Master' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Master' 'Grado' 'Secundaria'
#  'Secundaria' 'Doctorado' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Master' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Master' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Grado' 'Master' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Grado' 'Secundaria' 'Bachillerato' 'Master' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Doctorado' 'Secundaria' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Doctorado' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Doctorado' 'Secundaria' 'Grado' 'Secundaria' 'Master' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado'
#  'Master' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Grado' 'Secundaria' 'Secundaria' 'Master' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Secundaria'
#  'Grado' 'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Grado' 'Secundaria' 'Master'
#  'Doctorado' 'Grado' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado'
#  'Secundaria' 'Secundaria' 'Bachillerato']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np
estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.show()

# %%
# DIAGRAMA DE SECTORES
colores = {'red', 'blue', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()
